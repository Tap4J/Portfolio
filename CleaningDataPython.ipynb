# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('DataPython/movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %% [markdown]
# ### Missing data

# %%
for column in df.columns:
    pct_missing = np.mean(df[column].isnull())
    print('{} - {}%'.format(column, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
nan_rows = df['budget'].isna().sum()
print(nan_rows)
# Out:
# 2171

# %%
df['budget'] = df['budget'].fillna(0).astype('int64')

# %%
df['budget'] = df['budget'].astype('int64')

# %%
df['gross'] = df['gross'].fillna(0).astype('int64')

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %% [markdown]
# # Correct the year for realease
#
# **This is not working as there are erros. I will try different approach**
#
# ```df['Year released'] = df['released'].apply(lambda x: x.split(',')[1].strip().split()[0])```

# %%
# def function to extract year

def extract_year(date_string):
    if pd.isna(date_string):
        return None
    part = date_string.split(',')
    if len(part) >1:
        year_part = part[1].strip().split()
        if len(year_part) > 0:
            return year_part[0]

    return None

# %%
df['Year released'] = df['released'].apply(extract_year)
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %% [markdown]
# **Now I try some comparison if my year released and year are the same and correct**

# %%
df.dtypes
# Out:
# name              object
# rating            object
# genre             object
# year               int64
# released          object
# score            float64
# votes            float64
# director          object
# writer            object
# star              object
# country           object
# budget             int64
# gross              int64
# company           object
# runtime          float64
# Year released     object
# dtype: object

# %%
df['Year released'] = pd.to_numeric(df['Year released'], errors='coerce')
df['year release'] = df['Year released'].fillna(-1).astype(int)

# %%
df['Comparison']= df.apply(lambda row: 'Match' if row['year']== row['Year released'] else 'No match', axis= 1)
changes_count = df[df['Comparison']=='No match'].shape[0]
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
print(f'Number of not matching year: {changes_count}')
# Out:
# Number of not matching year: 1356

# %%
df.drop(columns=['Year released'], inplace=True)

# %%
df_not_matching = df[df['year'] != df['year release']]
df_not_matching.head()
# Out:
#                                 name rating      genre  year  \
# 8                        Superman II     PG     Action  1980
# 11            The Gods Must Be Crazy     PG  Adventure  1980
# 21                     Heaven's Gate      R  Adventure  1980
# 33  Cattle Annie and Little Britches     PG      Drama  1980
# 40          The Watcher in the Woods     PG     Family  1980
#
#                             released  score     votes        director  \
# 8      June 19, 1981 (United States)    6.8  101000.0  Richard Lester
# 11  October 26, 1984 (United States)    7.3   54000.0       Jamie Uys
# 21    April 24, 1981 (United States)    6.8   14000.0  Michael Cimino
# 33    April 24, 1981 (United States)    6.1     604.0  Lamont Johnson
# 40   October 9, 1981 (United States)    6.3    5700.0      John Hough
#
#             writer                star        country    budget      gross  \
# 8     Jerry Siegel        Gene Hackman  United States  54000000  108185706
# ...

# %%
row_sub = 0

for index, row in df.iterrows():
    if row['year']!= row['year release']:
        if pd.notna(row['year release']):
            df.at[index, 'year'] = row['year release']
            row_sub +=1

print(f'NUmber of substituions executed: {row_sub}')
# Out:
# NUmber of substituions executed: 1356
